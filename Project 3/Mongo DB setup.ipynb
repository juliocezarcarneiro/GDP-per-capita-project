'), ObjectId('67fe94e95080b84b0ef28e6d'), ObjectId('67fe94e95080b84b0ef28e6e'), ObjectId('67fe94e95080b84b0ef28e6f'), ObjectId('67fe94e95080b84b0ef28e70'), ObjectId('67fe94e95080b84b0ef28e71'), ObjectId('67fe94e95080b84b0ef28e72'), ObjectId('67fe94e95080b84b0ef28e73'), ObjectId('67fe94e95080b84b0ef28e74'), ObjectId('67fe94e95080b84b0ef28e75'), ObjectId('67fe94e95080b84b0ef28e76'), ObjectId('67fe94e95080b84b0ef28e77'), ObjectId('67fe94e95080b84b0ef28e78'), ObjectId('67fe94e95080b84b0ef28e79'), ObjectId('67fe94e95080b84b0ef28e7a'), ObjectId('67fe94e95080b84b0ef28e7b'), ObjectId('67fe94e95080b84b0ef28e7c'), ObjectId('67fe94e95080b84b0ef28e7d'), ObjectId('67fe94e95080b84b0ef28e7e'), ObjectId('67fe94e95080b84b0ef28e7f'), ObjectId('67fe94e95080b84b0ef28e80'), ObjectId('67fe94e95080b84b0ef28e81'), ObjectId('67fe94e95080b84b0ef28e82'), ObjectId('67fe94e95080b84b0ef28e83'), ObjectId('67fe94e95080b84b0ef28e84'), ObjectId('67fe94e95080b84b0ef28e85'), ObjectId('67fe94e95080b84b0ef28e86'), ObjectId('67fe94e95080b84b0ef28e87'), ObjectId('67fe94e95080b84b0ef28e88'), ObjectId('67fe94e95080b84b0ef28e89'), ObjectId('67fe94e95080b84b0ef28e8a'), ObjectId('67fe94e95080b84b0ef28e8b'), ObjectId('67fe94e95080b84b0ef28e8c'), ObjectId('67fe94e95080b84b0ef28e8d'), ObjectId('67fe94e95080b84b0ef28e8e'), ObjectId('67fe94e95080b84b0ef28e8f'), ObjectId('67fe94e95080b84b0ef28e90'), ObjectId('67fe94e95080b84b0ef28e91'), ObjectId('67fe94e95080b84b0ef28e92'), ObjectId('67fe94e95080b84b0ef2 ...

# %%
# Confirm insertion
print("✅ Data inserted into MongoDB.")
# Out:
# ✅ Data inserted into MongoDB.

# %%
# Show one document
pprint(collection.find_one())
# Out:
# {'Code': 'AFG',
#  'Country': 'Afghanistan',
#  'GDP per Capita': 1617.8264,
#  'Gini_Coefficient': 'No data',
#  'Health_Expenditure': 'No data',
#  'Income Class': 'Low-income countries',
#  'Population density per square kilometer': 30.863773,
#  'Year': 2000,
#  '_id': ObjectId('67fe94e95080b84b0ef28e2b')}

# %%
# Check for anoher country such as Canada
query = {"Country":"Canada"}
results = collection.find(query)
for result in results:
    pprint(result)
# Out:
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 47667.434,
#  'Gini_Coefficient': 0.33418295,
#  'Health_Expenditure': 2422.0178,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.5149403,
#  'Year': 2000,
#  '_id': ObjectId('67fe94e95080b84b0ef2918b')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 48036.625,
#  'Gini_Coefficient': 0.33554783,
#  'Health_Expenditure': 2608.879,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.551553,
#  'Year': 2001,
#  '_id': ObjectId('67fe94e95080b84b0ef2918c')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 48943.543,
#  'Gini_Coefficient': 0.3356031,
#  'Health_Expenditure': 2745.605,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.5881906,
#  'Year': 2002,
#  '_id': ObjectId('67fe94e95080b84b0ef2918d')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 49381.594,
#  'Gini_Coefficient': 0.33809465,
#  'Health_Expenditure': 2917.2874,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.6224282,
#  'Year': 2003,
#  '_id': ObjectId('67fe94e95080b84b0ef2918e')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 50436.293,
#  'Gini_Coefficient': 0.33776483,
#  'Health_Expenditure': 3078.594,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.656129,
#  'Year': 2004,
#  '_id': ObjectId('67fe94e95080b84b0ef2918f')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 51564.844,
#  'Gini_Coefficient': 0.33621806,
#  'Health_Expenditure': 3285.149,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.6911178,
#  'Year': 2005,
#  '_id': ObjectId('67fe94e95080b84b0ef29190')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 52391.38,
#  'Gini_Coefficient': 0.3409054,
#  'Health_Expenditure': 3565.4575,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.727414,
#  'Year': 2006,
#  '_id': ObjectId('67fe94e95080b84b0ef29191')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 52948.9,
#  'Gini_Coefficient': 0.33841008,
#  'Health_Expenditure': 3741.0686,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.7653034,
#  'Year': 2007,
#  '_id': ObjectId('67fe94e95080b84b0ef29192')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 52899.477,
#  'Gini_Coefficient': 0.33930567,
#  'Health_Expenditure': 3882.5107,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.8059144,
#  'Year': 2008,
#  '_id': ObjectId('67fe94e95080b84b0ef29193')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 50772.87,
#  'Gini_Coefficient': 0.33952153,
#  'Health_Expenditure': 4148.245,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.8488424,
#  'Year': 2009,
#  '_id': ObjectId('67fe94e95080b84b0ef29194')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 51763.676,
#  'Gini_Coefficient': 0.33592603,
#  'Health_Expenditure': 4286.291,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.8910017,
#  'Year': 2010,
#  '_id': ObjectId('67fe94e95080b84b0ef29195')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 52869.387,
#  'Gini_Coefficient': 0.32657078,
#  'Health_Expenditure': 4326.79,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.9317992,
#  'Year': 2011,
#  '_id': ObjectId('67fe94e95080b84b0ef29196')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 53217.715,
#  'Gini_Coefficient': 0.33539012,
#  'Health_Expenditure': 4447.523,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 3.9735644,
#  'Year': 2012,
#  '_id': ObjectId('67fe94e95080b84b0ef29197')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 53884.844,
#  'Gini_Coefficient': 0.3379898,
#  'Health_Expenditure': 4614.791,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.015766,
#  'Year': 2013,
#  '_id': ObjectId('67fe94e95080b84b0ef29198')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 54880.86,
#  'Gini_Coefficient': 0.33157605,
#  'Health_Expenditure': 4697.613,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.05455,
#  'Year': 2014,
#  '_id': ObjectId('67fe94e95080b84b0ef29199')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 54819.188,
#  'Gini_Coefficient': 0.33746484,
#  'Health_Expenditure': 4793.0625,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.091866,
#  'Year': 2015,
#  '_id': ObjectId('67fe94e95080b84b0ef2919a')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 54765.305,
#  'Gini_Coefficient': 0.32701823,
#  'Health_Expenditure': 5126.2197,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.1363673,
#  'Year': 2016,
#  '_id': ObjectId('67fe94e95080b84b0ef2919b')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 55756.26,
#  'Gini_Coefficient': 0.33308205,
#  'Health_Expenditure': 5268.3076,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.188156,
#  'Year': 2017,
#  '_id': ObjectId('67fe94e95080b84b0ef2919c')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 56470.46,
#  'Gini_Coefficient': 0.3250927,
#  'Health_Expenditure': 5456.3145,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.2435107,
#  'Year': 2018,
#  '_id': ObjectId('67fe94e95080b84b0ef2919d')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 56713.09,
#  'Gini_Coefficient': 0.31749648,
#  'Health_Expenditure': 5497.487,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.29903,
#  'Year': 2019,
#  '_id': ObjectId('67fe94e95080b84b0ef2919e')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 53274.91,
#  'Gini_Coefficient': 'No data',
#  'Health_Expenditure': 6175.26,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.3432875,
#  'Year': 2020,
#  '_id': ObjectId('67fe94e95080b84b0ef2919f')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 55781.7,
#  'Gini_Coefficient': 'No data',
#  'Health_Expenditure': 6552.219,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.3753924,
#  'Year': 2021,
#  '_id': ObjectId('67fe94e95080b84b0ef291a0')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 56872.605,
#  'Gini_Coefficient': 'No data',
#  'Health_Expenditure': 6443.4224,
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.417173,
#  'Year': 2022,
#  '_id': ObjectId('67fe94e95080b84b0ef291a1')}
# {'Code': 'CAN',
#  'Country': 'Canada',
#  'GDP per Capita': 55918.93,
#  'Gini_Coefficient': 'No data',
#  'Health_Expenditure': 'No data',
#  'Income Class': 'High-income countries',
#  'Population density per square kilometer': 4.4715433,
#  'Year': 2023,
#  '_id': ObjectId('67fe94e95080b84b0ef291a2')}
